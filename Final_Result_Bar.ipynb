# %%
import numpy as np
import matplotlib.pyplot as plt

# Data
models = ['Accuracy','Recall','Specificity','Precision','F1-Score']
CNN_Hybrid = [0.9954,0.9885,0.9970,0.9891,0.9888] 
CNN_Max = [0.9916, 0.9791,0.9946,0.9798, 0.9795] 
CNN_Min = [0.9853,0.9633, 0.9907,0.9682,0.9657] 
Inception_V3 = [0.9815,0.9537 ,0.9883 , 0.9652,0.9594] 
Resnet_50 = [0.9447,0.8611,0.9655 ,0.8645 , 0.8615] 
Resnet_152=[ 0.9628,0.9165,0.9773, 0.9310,0.9236]
# Plotting
fig, ax = plt.subplots(figsize=(12, 8))
colors = ['skyblue', 'salmon', 'lightgreen', 'gold', 'mediumpurple', 'lightcoral']
bar_width = 0.15
index = np.arange(len(models))

metrics = [CNN_Hybrid,CNN_Max,CNN_Min,Inception_V3,Resnet_50,Resnet_152]
metric_labels = ['CNN_Hybrid', 'CNN_Max', 'CNN_Min', 'Inception_V3', 'Resnet_50','Resnet_152']

for i in range(6):
    ax.bar(index + i * bar_width, metrics[i], bar_width, color=colors[i], label=metric_labels[i])
    for j in range(len(models)):
        # Adjust y-coordinate to be above each bar
        ax.text(index[j] + i * bar_width, metrics[i][j] + 0.005, '{:.4f}'.format(metrics[i][j]), ha='center', va='bottom', rotation=90)

ax.set_xlabel('Models')
ax.set_ylabel('Metrics Value')
ax.set_title('Performance Metrics of Different Models')
ax.set_xticks(index + 2 * bar_width)
ax.set_xticklabels(models)
ax.legend()

# Adjust y-axis limits and ticks
plt.ylim(0.8, 1.0)
plt.yticks(np.arange(0.8, 1.05, 0.02))

plt.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Data
models = ['Accuracy','Recall','Specificity','Precision','F1-Score']
CNN_Hybrid = [99.54, 98.85, 99.70, 98.91, 98.88]
CNN_Max = [99.16, 97.91, 99.46, 97.98, 97.95]
CNN_Min = [98.53, 96.33, 99.07, 96.82, 96.57]
Inception_V3 = [98.15, 95.37, 98.83, 96.52, 95.94]
Resnet_50 = [94.47, 86.11, 96.55, 86.45, 86.15]
Resnet_152 = [96.28, 91.65, 97.73, 93.10, 92.36]

# Plotting
fig, ax = plt.subplots(figsize=(12, 8))
colors = ['skyblue', 'salmon', 'lightgreen', 'gold', 'mediumpurple', 'lightcoral']
bar_width = 0.15
index = np.arange(len(models))

metrics = [CNN_Hybrid, CNN_Max, CNN_Min, Inception_V3, Resnet_50, Resnet_152]
metric_labels = ['CNN_Hybrid', 'CNN_Max', 'CNN_Min', 'Inception_V3', 'Resnet_50', 'Resnet_152']

for i in range(6):
    ax.bar(index + i * bar_width, metrics[i], bar_width, color=colors[i], label=metric_labels[i])
    for j in range(len(models)):
        # Adjust y-coordinate to be above each bar
        ax.text(index[j] + i * bar_width, metrics[i][j] + 0.2, '{:.2f}'.format(metrics[i][j]), ha='center', va='bottom', rotation=90)

ax.set_xlabel('Models')
ax.set_ylabel('Metrics Value (%)')
ax.set_title('Performance Metrics of Different Models')
ax.set_xticks(index + 2 * bar_width)
ax.set_xticklabels(models)
ax.legend()

# Adjust y-axis limits and ticks
plt.ylim(80, 102)
plt.yticks(np.arange(80, 101, 2))

plt.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Data
models = ['Accuracy', 'Recall', 'Specificity', 'Precision', 'F1-Score']
CNN_Hybrid = [99.54, 98.85, 99.70, 98.88, 98.86]
CNN_Max = [99.16, 97.91, 99.46, 97.98, 97.95]
CNN_Min = [98.53, 96.33, 99.07, 96.82, 96.57]
Inception_V3 = [98.15, 95.37, 98.83, 96.52, 95.94]
Resnet_50 = [94.47, 86.11, 96.55, 86.45, 86.15]
Resnet_152 = [96.28, 91.65, 97.73, 93.10, 92.36]

# Plotting
fig, ax = plt.subplots(figsize=(12, 8))
colors = ['skyblue', 'salmon', 'lightgreen', 'gold', 'mediumpurple', 'lightcoral']
bar_width = 0.14  # reduced width
index = np.arange(len(models))

metrics = [CNN_Hybrid, CNN_Max, CNN_Min, Inception_V3, Resnet_50, Resnet_152]
metric_labels = ['CNN_Hybrid', 'CNN_Max', 'CNN_Min', 'Inception_V3', 'Resnet_50', 'Resnet_152']

for i in range(6):
    ax.bar(index + i * bar_width, metrics[i], bar_width, color=colors[i], label=metric_labels[i])
    for j in range(len(models)):
        # Adjust y-coordinate to be above each bar
        ax.text(index[j] + i * bar_width, metrics[i][j] + 0.2, '{:.2f}'.format(metrics[i][j]), ha='center', va='bottom', rotation=90)

ax.set_xlabel('Models')
ax.set_ylabel('Metrics Value (%)')
ax.set_title('Performance Metrics of Different Models')
ax.set_xticks(index + 2.5 * bar_width)  # Adjusted offset
ax.set_xticklabels(models)
ax.legend()

# Adjust y-axis limits and ticks
plt.ylim(80, 102)
plt.yticks(np.arange(80, 101, 2))

plt.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Data
models = ['Accuracy', 'Recall', 'Specificity', 'Precision', 'F1-Score']
CNN_Hybrid = [99.54, 98.85, 99.70, 98.88, 98.86]
CNN_Max = [99.16, 97.91, 99.46, 97.98, 97.95]
CNN_Min = [98.53, 96.33, 99.07, 96.82, 96.57]
Inception_V3 = [98.15, 95.37, 98.83, 96.52, 95.94]
Resnet_50 = [94.47, 86.11, 96.55, 86.45, 86.15]
Resnet_152 = [96.28, 91.65, 97.73, 93.10, 92.36]

# Plotting
fig, ax = plt.subplots(figsize=(12, 8))
colors = ['skyblue', 'salmon', 'lightgreen', 'gold', 'mediumpurple', 'lightcoral']
bar_width = 0.14  # reduced width
index = np.arange(len(models))

metrics = [CNN_Hybrid, CNN_Max, CNN_Min, Inception_V3, Resnet_50, Resnet_152]
metric_labels = ['Proposed_Model', 'CNN_Max', 'CNN_Min', 'Inception_V3', 'Resnet_50', 'Resnet_152']

for i in range(6):
    ax.bar(index + i * bar_width, metrics[i], bar_width, color=colors[i], label=metric_labels[i])
    for j in range(len(models)):
        # Adjust y-coordinate to be above each bar
        ax.text(index[j] + i * bar_width, metrics[i][j] + 0.2, '{:.2f}'.format(metrics[i][j]), ha='center', va='bottom', rotation=90)

ax.set_xlabel('Models')
ax.set_ylabel('Metrics Value (%)')
ax.set_title('Performance Metrics of Different Models')
ax.set_xticks(index + 2.5 * bar_width)  # Adjusted offset
ax.set_xticklabels(models)
ax.legend()

# Adjust y-axis limits and ticks
plt.ylim(80, 102)
plt.yticks(np.arange(80, 101, 2))

plt.tight_layout()
plt.show()
