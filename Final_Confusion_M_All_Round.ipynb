# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Replace with your true labels and predicted labels
true_labels = ['L', 'N', 'P', 'R', 'V'] 
predicted_labels = ['L', 'N', 'P', 'R', 'V']

# Confusion matrix values
conf_matrix_values = [
    [400, 0, 0, 0, 0],
    [0, 398, 0, 1, 1],
    [0, 0, 400, 0, 0],
    [0, 1, 0, 399, 0],
    [2, 1, 0, 0, 397]
]

plt.figure(figsize=(10, 7))
sns.set(font_scale=1.4)  # Set font size
sns.heatmap(conf_matrix_values,
            annot=True,
            fmt='d',  # Use 'd' for integer values
            cmap='Blues',
            xticklabels=predicted_labels,
            yticklabels=true_labels,
            cbar=True)  # Add the color bar
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.title('Confusion Matrix')
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Replace with your true labels and predicted labels
true_labels = ['L', 'N', 'P', 'R', 'V'] 
predicted_labels = ['L', 'N', 'P', 'R', 'V']

# Confusion matrix values
conf_matrix_values = [
    [400, 0, 0, 0, 0],
    [0, 400, 0, 0, 0],
    [0, 0, 400, 0, 0],
    [0, 2, 0, 398, 0],
    [1, 0, 0, 0, 399]
]

plt.figure(figsize=(10, 7))
sns.set(font_scale=1.4)  # Set font size
sns.heatmap(conf_matrix_values,
            annot=True,
            fmt='d',  # Use 'd' for integer values
            cmap='Blues',
            xticklabels=predicted_labels,
            yticklabels=true_labels,
            cbar=True)  # Add the color bar
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.title('Confusion Matrix')
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Replace with your true labels and predicted labels
true_labels = ['L', 'N', 'P', 'R', 'V'] 
predicted_labels = ['L', 'N', 'P', 'R', 'V']

# Confusion matrix values
conf_matrix_values = [
    [400, 0, 0, 0, 0],
    [0, 394, 3, 1, 2],
    [0, 0, 400, 0, 0],
    [0, 0, 0, 400, 0],
    [0, 2, 0, 1, 397]
]

plt.figure(figsize=(10, 7))
sns.set(font_scale=1.4)  # Set font size
sns.heatmap(conf_matrix_values,
            annot=True,
            fmt='d',  # Use 'd' for integer values
            cmap='Blues',
            xticklabels=predicted_labels,
            yticklabels=true_labels,
            cbar=True)  # Add the color bar
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.title('Confusion Matrix')
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Replace with your true labels and predicted labels
true_labels = ['L', 'N', 'P', 'R', 'V'] 
predicted_labels = ['L', 'N', 'P', 'R', 'V']

# Confusion matrix values
conf_matrix_values = [
    [395, 2, 3, 0, 0],
    [43, 352, 0, 4, 1],
    [0, 0, 399, 0, 1],
    [0, 0, 0, 400, 0],
    [0, 0, 0, 0, 400]
]

plt.figure(figsize=(10, 7))
sns.set(font_scale=1.4)  # Set font size
sns.heatmap(conf_matrix_values,
            annot=True,
            fmt='d',  # Use 'd' for integer values
            cmap='Blues',
            xticklabels=predicted_labels,
            yticklabels=true_labels,
            cbar=True)  # Add the color bar
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.title('Confusion Matrix')
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Replace with your true labels and predicted labels
true_labels = ['L', 'N', 'P', 'R', 'V'] 
predicted_labels = ['L', 'N', 'P', 'R', 'V']

# Confusion matrix values
conf_matrix_values = [
    [400, 0, 0, 0, 0],
    [0, 400, 0, 0, 0],
    [0, 7, 358, 35, 0],
    [0, 1, 0, 399, 0],
    [0, 0, 0, 0, 400]
]

plt.figure(figsize=(10, 7))
sns.set(font_scale=1.4)  # Set font size
sns.heatmap(conf_matrix_values,
            annot=True,
            fmt='d',  # Use 'd' for integer values
            cmap='Blues',
            xticklabels=predicted_labels,
            yticklabels=true_labels,
            cbar=True)  # Add the color bar
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.title('Confusion Matrix')
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# Data
true_labels = ['L', 'N', 'P', 'R', 'V'] 
predicted_labels = ['L', 'N', 'P', 'R', 'V']
conf_matrix_values = [
    [1995, 2, 3, 0, 0],
    [43, 1944, 3, 6, 4],
    [0, 7, 1957, 35, 1],
    [0, 4, 0, 1996, 0],
    [3, 3, 0, 1, 1993]
]

# Plotting
plt.figure(figsize=(10, 7))
sns.set(font_scale=1.4)  # Set font size
sns.heatmap(conf_matrix_values,
            annot=True,
            fmt='g',
            cmap='Blues',
            xticklabels=predicted_labels,
            yticklabels=true_labels,
            cbar=False)  # Remove the color bar
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.title('Confusion Matrix')
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Replace with your true labels and predicted labels
true_labels = ['L', 'N', 'P', 'R', 'V'] 
predicted_labels = ['L', 'N', 'P', 'R', 'V']

# Confusion matrix values
conf_matrix_values = [
    [1995, 2, 3, 0, 0],
    [43, 1944, 3, 6, 4],
    [0, 7, 1957, 35, 1],
    [0, 4, 0, 1996, 0],
    [3, 3, 0, 1, 1993]
]

plt.figure(figsize=(10, 7))
sns.set(font_scale=1.4)  # Set font size
sns.heatmap(conf_matrix_values,
            annot=True,
            fmt='d',  # Use 'd' for integer values
            cmap='Blues',
            xticklabels=predicted_labels,
            yticklabels=true_labels,
            cbar=True,  # Add the color bar
            vmax=2000)  # Set the maximum value for color scale
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.title('Confusion Matrix')
plt.show()

# %%
#Max-Pooling
import matplotlib.pyplot as plt
import seaborn as sns

# Replace with your true labels and predicted labels
true_labels = ['L', 'N', 'P', 'R', 'V'] 
predicted_labels = ['L', 'N', 'P', 'R', 'V']

# Confusion matrix values
conf_matrix_values = [
    [1975, 12, 2, 5, 6],
    [47, 1945, 0, 6, 2],
    [3, 21, 1929, 45, 2],
    [0, 1, 0, 1999, 0],
    [21, 4, 21, 11, 1943]
]

plt.figure(figsize=(10, 7))
sns.set(font_scale=1.4)  # Set font size
sns.heatmap(conf_matrix_values,
            annot=True,
            fmt='d',  # Use 'd' for integer values
            cmap='Blues',
            xticklabels=predicted_labels,
            yticklabels=true_labels,
            cbar=True,  # Add the color bar
            vmax=2000)  # Set the maximum value for color scale
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.title('Confusion Matrix')
plt.show()

# %%
#Min-Pooling
import matplotlib.pyplot as plt
import seaborn as sns

# Replace with your true labels and predicted labels
true_labels = ['L', 'N', 'P', 'R', 'V'] 
predicted_labels = ['L', 'N', 'P', 'R', 'V']

# Confusion matrix values
conf_matrix_values = [
    [1843, 0, 0, 0, 157],
    [114, 1844, 5, 7, 30],
    [0, 21, 1954, 10, 15],
    [0, 2, 1, 1997, 0],
    [0, 1, 4, 0, 1995]
]

plt.figure(figsize=(10, 7))
sns.set(font_scale=1.4)  # Set font size
sns.heatmap(conf_matrix_values,
            annot=True,
            fmt='d',  # Use 'd' for integer values
            cmap='Blues',
            xticklabels=predicted_labels,
            yticklabels=true_labels,
            cbar=True)  # Add the color bar
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.title('Confusion Matrix')
plt.show()

# %%
#Inception_V3
import matplotlib.pyplot as plt
import seaborn as sns

# Replace with your true labels and predicted labels
true_labels = ['L', 'N', 'P', 'R', 'V'] 
predicted_labels = ['L', 'N', 'P', 'R', 'V']

# Confusion matrix values
conf_matrix_values = [
    [1985, 0, 3, 1, 11],
    [1, 1920, 11, 13, 55],
    [3, 71, 1800, 0, 126],
    [6, 1, 2, 1832, 159],
    [0, 0, 0, 0, 2000]
]

plt.figure(figsize=(10, 7))
sns.set(font_scale=1.4)  # Set font size
sns.heatmap(conf_matrix_values,
            annot=True,
            fmt='d',  # Use 'd' for integer values
            cmap='Blues',
            xticklabels=predicted_labels,
            yticklabels=true_labels,
            cbar=True)  # Add the color bar
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.title('Confusion Matrix')
plt.show()

# %%
#Resnet50
import matplotlib.pyplot as plt
import seaborn as sns

# Replace with your true labels and predicted labels
true_labels = ['L', 'N', 'P', 'R', 'V'] 
predicted_labels = ['L', 'N', 'P', 'R', 'V']

# Confusion matrix values
conf_matrix_values = [
    [1952, 1, 1, 0, 46],
    [253, 1609, 81, 0, 51],
    [36, 13, 1924, 21, 6],
    [307, 0, 283, 1139, 271],
    [10, 0, 2, 1, 1987]
]

plt.figure(figsize=(10, 7))
sns.set(font_scale=1.4)  # Set font size
sns.heatmap(conf_matrix_values,
            annot=True,
            fmt='d',  # Use 'd' for integer values
            cmap='Blues',
            xticklabels=predicted_labels,
            yticklabels=true_labels,
            cbar=True)  # Add the color bar
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.title('Confusion Matrix')
plt.show()

# %%
#R152

# %%
#Proposed Model Fold1
import matplotlib.pyplot as plt
import seaborn as sns

# Replace with your true labels and predicted labels
true_labels = ['Shockable (V)','Non-Shockable'] 
predicted_labels = ['Shockable (V)','Non-Shockable']

# Confusion matrix values
conf_matrix_values = [
    [397,3],
    [3,1597]
]

plt.figure(figsize=(5, 3))
sns.set(font_scale=1)  # Set font size
sns.heatmap(conf_matrix_values,
            annot=True,
            fmt='d',  # Use 'd' for integer values
            cmap='Blues',
            xticklabels=predicted_labels,
            yticklabels=true_labels,
            cbar=True)  # Add the color bar
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.title('Confusion Matrix')
plt.show()

# %%
#Proposed Model Fold2
import matplotlib.pyplot as plt
import seaborn as sns

# Replace with your true labels and predicted labels
true_labels = ['Shockable (V)','Non-Shockable'] 
predicted_labels = ['Shockable (V)','Non-Shockable']

# Confusion matrix values
conf_matrix_values = [
    [399,1],
    [2,1598]
]

plt.figure(figsize=(5, 3))
sns.set(font_scale=1)  # Set font size
sns.heatmap(conf_matrix_values,
            annot=True,
            fmt='d',  # Use 'd' for integer values
            cmap='Blues',
            xticklabels=predicted_labels,
            yticklabels=true_labels,
            cbar=True)  # Add the color bar
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.title('Confusion Matrix')
plt.show()

# %%
#Proposed Model Fold3
import matplotlib.pyplot as plt
import seaborn as sns

# Replace with your true labels and predicted labels
true_labels = ['Shockable (V)','Non-Shockable'] 
predicted_labels = ['Shockable (V)','Non-Shockable']

# Confusion matrix values
conf_matrix_values = [
    [397,3],
    [6,1594]
]

plt.figure(figsize=(5, 3))
sns.set(font_scale=1)  # Set font size
sns.heatmap(conf_matrix_values,
            annot=True,
            fmt='d',  # Use 'd' for integer values
            cmap='Blues',
            xticklabels=predicted_labels,
            yticklabels=true_labels,
            cbar=True)  # Add the color bar
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.title('Confusion Matrix')
plt.show()

# %%
#Proposed Model Fold4
import matplotlib.pyplot as plt
import seaborn as sns

# Replace with your true labels and predicted labels
true_labels = ['Shockable (V)','Non-Shockable'] 
predicted_labels = ['Shockable (V)','Non-Shockable']

# Confusion matrix values
conf_matrix_values = [
    [400,0],
    [54,1546]
]

plt.figure(figsize=(5, 3))
sns.set(font_scale=1)  # Set font size
sns.heatmap(conf_matrix_values,
            annot=True,
            fmt='d',  # Use 'd' for integer values
            cmap='Blues',
            xticklabels=predicted_labels,
            yticklabels=true_labels,
            cbar=True)  # Add the color bar
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.title('Confusion Matrix')
plt.show()

# %%
#Proposed Model Fold5
import matplotlib.pyplot as plt
import seaborn as sns

# Replace with your true labels and predicted labels
true_labels = ['Shockable (V)','Non-Shockable'] 
predicted_labels = ['Shockable (V)','Non-Shockable']

# Confusion matrix values
conf_matrix_values = [
    [400,0],
    [43,1557]
]

plt.figure(figsize=(5, 3))
sns.set(font_scale=1)  # Set font size
sns.heatmap(conf_matrix_values,
            annot=True,
            fmt='d',  # Use 'd' for integer values
            cmap='Blues',
            xticklabels=predicted_labels,
            yticklabels=true_labels,
            cbar=True)  # Add the color bar
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.title('Confusion Matrix')
plt.show()

# %%
#Proposed Model 
import matplotlib.pyplot as plt
import seaborn as sns

# Replace with your true labels and predicted labels
true_labels = ['Shockable (V)','Non-Shockable'] 
predicted_labels = ['Shockable (V)','Non-Shockable']

# Confusion matrix values
conf_matrix_values = [
    [1993,7],
    [8,7892]
]

plt.figure(figsize=(5, 3))
sns.set(font_scale=1)  # Set font size
sns.heatmap(conf_matrix_values,
            annot=True,
            fmt='d',  # Use 'd' for integer values
            cmap='Blues',
            xticklabels=predicted_labels,
            yticklabels=true_labels,
            cbar=True)  # Add the color bar
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.title('Confusion Matrix')
plt.show()

# %%
#Maxpooling
import matplotlib.pyplot as plt
import seaborn as sns

# Replace with your true labels and predicted labels
true_labels = ['Shockable (V)','Non-Shockable'] 
predicted_labels = ['Shockable (V)','Non-Shockable']

# Confusion matrix values
conf_matrix_values = [
    [1943,57],
    [52,7848]
]

plt.figure(figsize=(5, 3))
sns.set(font_scale=1)  # Set font size
sns.heatmap(conf_matrix_values,
            annot=True,
            fmt='d',  # Use 'd' for integer values
            cmap='Blues',
            xticklabels=predicted_labels,
            yticklabels=true_labels,
            cbar=True)  # Add the color bar
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.title('Confusion Matrix')
plt.show()

# %%
#Minpooling
import matplotlib.pyplot as plt
import seaborn as sns

# Replace with your true labels and predicted labels
true_labels = ['Shockable (V)','Non-Shockable'] 
predicted_labels = ['Shockable (V)','Non-Shockable']

# Confusion matrix values
conf_matrix_values = [
    [1995,5],
    [362,7638]
]

plt.figure(figsize=(5, 3))
sns.set(font_scale=1)  # Set font size
sns.heatmap(conf_matrix_values,
            annot=True,
            fmt='d',  # Use 'd' for integer values
            cmap='Blues',
            xticklabels=predicted_labels,
            yticklabels=true_labels,
            cbar=True)  # Add the color bar
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.title('Confusion Matrix')
plt.show()

# %%
#Inception V3
import matplotlib.pyplot as plt
import seaborn as sns

# Replace with your true labels and predicted labels
true_labels = ['Shockable (V)','Non-Shockable'] 
predicted_labels = ['Shockable (V)','Non-Shockable']

# Confusion matrix values
conf_matrix_values = [
    [2000,0],
    [463,7537]
]

plt.figure(figsize=(5, 3))
sns.set(font_scale=1)  # Set font size
sns.heatmap(conf_matrix_values,
            annot=True,
            fmt='d',  # Use 'd' for integer values
            cmap='Blues',
            xticklabels=predicted_labels,
            yticklabels=true_labels,
            cbar=True)  # Add the color bar
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.title('Confusion Matrix')
plt.show()

# %%
#Resnet 50
import matplotlib.pyplot as plt
import seaborn as sns

# Replace with your true labels and predicted labels
true_labels = ['Shockable (V)','Non-Shockable'] 
predicted_labels = ['Shockable (V)','Non-Shockable']

# Confusion matrix values
conf_matrix_values = [
    [1987,13],
    [1376,6624]
]

plt.figure(figsize=(5, 3))
sns.set(font_scale=1)  # Set font size
sns.heatmap(conf_matrix_values,
            annot=True,
            fmt='d',  # Use 'd' for integer values
            cmap='Blues',
            xticklabels=predicted_labels,
            yticklabels=true_labels,
            cbar=True)  # Add the color bar
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.title('Confusion Matrix')
plt.show()

# %%
#Resnet 152
import matplotlib.pyplot as plt
import seaborn as sns

# Replace with your true labels and predicted labels
true_labels = ['Shockable (V)','Non-Shockable'] 
predicted_labels = ['Shockable (V)','Non-Shockable']

# Confusion matrix values
conf_matrix_values = [
    [1704,296],
    [539,7461]
]

plt.figure(figsize=(5, 3))
sns.set(font_scale=1)  # Set font size
sns.heatmap(conf_matrix_values,
            annot=True,
            fmt='d',  # Use 'd' for integer values
            cmap='Blues',
            xticklabels=predicted_labels,
            yticklabels=true_labels,
            cbar=True)  # Add the color bar
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.title('Confusion Matrix')
plt.show()
